# %%
from eautoencoder import *

# %%
xtest, yhat = test_multi(neuron=500)
# Out:
# Temps d'exécution:  120.01143407821655
# Score de bonne classification:  0.8420528151469856

# %%
import random

for n in range(10):
	i = random.randint(0, len(xtest) - 1)
	show_usps(xtest[i], yhat[i])
	plt.show()
